# %% [markdown]
# # http://mentat.za.net/refer/ay250_skimage.tar.gz

# %% [markdown]
# # CSE: scipy.ndimage and scikit-image
#
# <img src="files/img_proc_stack.svg"/>

# %% [markdown]
# - [ndimage docs](http://docs.scipy.org/doc/scipy/reference/ndimage.html)

# %%
# %gui qt

# %%
from scipy import ndimage as ndi
ndi?

# %%
# %qtconsole

# %% [markdown]
# ## Counting grains and bubbles
#
# This Scanning Element Microscopy image shows a glass sample
# (light gray matrix) with some bubbles (black) and unmolten
# sand grains (dark gray). We wish to determine the fraction
# of the sample covered by these three phases,
# and to estimate the number of sand grains and bubbles,
# their average sizes, etc.

# %% [markdown]
# ### Loading the slide

# %%
import matplotlib.pyplot as plt
import numpy as np

img = np.flipud(plt.imread('bubbles.jpg'))
plt.imshow(img, cmap=plt.cm.gray, interpolation='nearest');

# %% [markdown]
# ### Remove banner

# %%
img_clean = img[:880, :]
plt.imshow(img_clean, cmap=plt.cm.gray, interpolation='nearest');

# %% [markdown]
# ### Filter to get rid of speckles

# %%
import scipy.ndimage as ndi
img_med = ndi.median_filter(img_clean, size=5)
plt.imshow(img_med, cmap=plt.cm.gray, interpolation='nearest');

# %% [markdown]
# ### Find threshold values

# %%
plt.hist(img_med.flat, bins=40, range=(0, 150));

# %% [markdown]
# ### Separate layers by thresholding

# %%
bubbles = (img_med <= 50)
sand = (img_med > 50) & (img_med <= 120)
glass = (img_med > 120)

def plot_images(cmap=plt.cm.gray):
    for n, (name, image) in \
        enumerate([('Original', img_med),
                   ('Bubbles', bubbles),
                   ('Sand', sand),
                   ('Glass', glass)]):
    
        plt.subplot(2, 2, n + 1)
        plt.imshow(image, cmap=cmap)
        plt.title(name)
        plt.axis('off')
        
plot_images();

# %% [markdown]
# ### Visualise layers

# %%
def plot_color_overlay():
    all_layers = np.zeros((img_clean.shape[0],
                           img_clean.shape[1], 3)) # Color image

    # You shouldn't run this if bubbles isn't a mask
    # -- otherwise, fancy indexing instead of masking
    assert(bubbles.dtype == np.bool)
    
    all_layers[bubbles] = (1, 0, 0)
    all_layers[sand] = (1, 1, 0)
    all_layers[glass] = (0, 0, 1)

    plt.imshow(all_layers)

plot_color_overlay()

# %% [markdown]
# ### Clean up shapes found

# %%
for img in (sand, bubbles, glass):
    img[:] = ndi.binary_opening(img, np.ones((5, 5)))
    img[:] = ndi.binary_closing(img, np.ones((5, 5)))
    
plot_images()

# %% [markdown]
# ### Label connected components

# %%
# Convert to int so we can store the labels
bubbles = bubbles.astype(int)
sand = sand.astype(int)
glass = glass.astype(int)

for name, img in [('Sand', sand),
                  ('Bubbles', bubbles),
                  ('Glass', glass)]:
    labels, count = ndi.label(img)
    print '%s regions found in %s' % (count, name)
    img[:] = labels
    
    obj_areas = [np.sum(labels == i) for \
                 i in range(1, labels.max())]
    print "Mean obj area %d" % np.mean(obj_areas)

plot_images(cmap=plt.cm.spectral)
# Out:
# 115 regions found in Sand
# Mean obj area 1769
# 70 regions found in Bubbles
# Mean obj area 2516
# 27 regions found in Glass
# Mean obj area 19111

# %% [markdown]
# <img src="files/skimage_logo.png" style="float: left;"/>
# <div style="clear: both;">

# %% [markdown]
# - [Homepage](http://skimage.org)
# - [Documentation](http://scikits-image.org/docs/dev/)
# - [Gallery](http://scikits-image.org/docs/dev/auto_examples/index.html)

# %% [markdown]
# ### Front page example

# %%
from skimage import data, filter, io

image = data.coins()
edges = filter.sobel(image)
io.imshow(edges)

# %%
import matplotlib.pyplot as plt
plt.imshow(edges, cmap=plt.cm.gray, interpolation='nearest');

# %% [markdown]
# ### File input/output

# %%
from skimage import io

img = io.imread('bubbles.jpg')
io.imshow(img)

# %%
io.use_plugin('qt')
io.imshow(img, fancy=True)
io.show()

# %%
io.use_plugin('matplotlib')
io.imshow(io.pop())

# %%
io.use_plugin('fits')

ngc7635 = io.imread('ngc7635_041008_15i75m_L.FIT')
io.imshow(ngc7635)

io.use_plugin('matplotlib')
# Out:
# File may have been truncated: actual file length (21424512) is smaller than the expected size (21427200)

# %% [markdown]
# ### Data types and ranges
#
# [Data-type documentation](http://scikits-image.org/docs/dev/user_guide/data_types.html)

# %%
print ngc7635.dtype
print ngc7635.min(), ngc7635.max()
# Out:
# float32
# 100.0 65535.0

# %%
# Strange range--should fail
from skimage import filter
filter.sobel(ngc7635)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e77797697b64> in <module>()
#       1 # Strange range--should fail
#       2 from skimage import filter
# ----> 3 filter.sobel(ngc7635)
#
# /home/stefan/src/scikit-image/skimage/filter/edges.pyc in sobel(image, mask)
#      60     has to be further processed to perform edge detection.
#      61     """
# ---> 62     return np.sqrt(hsobel(image, mask)**2 + vsobel(image, mask)**2)
#      63
#      64
#
# /home/stefan/src/scikit-image/skimage/filter/edges.pyc in hsobel(image, mask)
#      90
#      91     """
# ---> 92     image = img_as_float(image)
#      93     result = np.abs(convolve(image,
#      94                              np.array([[ 1, 2, 1],
#
# /home/stefan/src/scikit-image/skimage/util/dtype.pyc in img_as_float(image, force_copy)
#     270
#     271     """
# --> 272     return convert(image, np.float64, force_copy)
#     273
#     274
#
# /home/stefan/src/scikit-image/skimage/util/dtype.pyc in convert(image, dtype, force_copy, uniform)
#     174     if kind_in == 'f':
#     175         if np.min(image) < -1.0 or np.max(image) > 1.0:
# --> 176             raise ValueError("Images of type float must be between -1 and 1.")
#     177         if kind == 'f':
#     178             # floating point -> floating point
#
# ValueError: Images of type float must be between -1 and 1.

# %%
# This should be successful

from skimage import exposure
ngc7635_ = exposure.rescale_intensity(ngc7635, in_range=(0, 65535))
filter.sobel(ngc7635_)
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   1.69985462e-02,   1.83780604e-02, ...,
#           9.96635057e-02,   2.68085374e-01,   0.00000000e+00],
#        [  0.00000000e+00,   1.68612418e-03,   2.13964835e-04, ...,
#           9.89586634e-02,   2.69367535e-01,   0.00000000e+00],
#        ...,
#        [  0.00000000e+00,   1.31719506e-01,   1.29457999e-01, ...,
#           5.19238830e-02,   2.77412382e-01,   0.00000000e+00],
#        [  0.00000000e+00,   2.23200615e-01,   2.24204697e-01, ...,
#           2.71920608e-01,   3.04454611e-01,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
from skimage import exposure
io.imshow(exposure.rescale_intensity(ngc7635_, in_range=(0, 0.25)))

# %%
# Conversion functions
from skimage import img_as_float, img_as_int, img_as_ubyte

print img_as_float(ngc7635_).max()
print img_as_int(ngc7635_).max()
print img_as_ubyte(ngc7635_).max()
# Out:
# 1.0
# skimage.dtype_converter: WARNING: Possible precision loss when converting from float32 to int16
# 32767
# skimage.dtype_converter: WARNING: Possible precision loss when converting from float32 to uint8
# 255

# %% [markdown]
# ### Obtaining test data

# %%
from skimage import data
io.imshow(data.camera())

# %%
io.imshow(data.coins())
data.coins?

# %% [markdown]
# ### Constructing a pipeline
#
# In ``skimage``, functions should take any data-type image as input, but produce whichever data-type
# output it can generate most efficiently.  This means that you can always build pipelines:

# %%
img = data.camera()

f, (ax0, ax1) = plt.subplots(1, 2, figsize=(8, 5))
ax0.imshow(filter.canny(img), cmap=plt.cm.gray)
ax0.set_title('Canny')

pipeline = filter.canny(filter.tv_denoise(img, weight=1))
ax1.imshow(pipeline, plt.cm.gray)
ax1.set_title('Canny + TV denoise');

# %% [markdown]
# ### Shortest paths

# %% [markdown]
# See http://scikit-image.org/docs/dev/api/api.html

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('6NcIJXTlugc')
# Out:
#             <iframe
#                 width="400"
#                 height="300"
#                 src="http://www.youtube.com/embed/6NcIJXTlugc"
#                 frameborder="0"
#                 allowfullscreen
#             ></iframe>

# %% [markdown]
# ### Color spaces

# %%
# Turtle image by Brocken Inaglory (http://commons.wikimedia.org/wiki/File:Hawaii_turtle_2.JPG)

io.use_plugin('qt')
img = io.imread('Hawaii_turtle.jpg')

# Explore HSV color space
io.imshow(img, fancy=True)
io.show()

io.use_plugin('matplotlib')

# %%
from skimage import data, io, img_as_float
import numpy as np
import matplotlib.pyplot as plt

alpha = 0.6

img = img_as_float(data.camera())
rows, cols = img.shape

# Construct a colour image to superimpose
color_mask = np.zeros((rows, cols, 3))
color_mask[30:140, 30:140] = [1, 0, 0]  # Red block
color_mask[170:270, 40:120] = [0, 1, 0] # Green block
color_mask[200:350, 200:350] = [0, 0, 1] # Blue block

f, (ax0, ax1) = plt.subplots(1, 2, figsize=(12, 8),
                             subplot_kw={'xticks': [], 'yticks': []})
ax0.imshow(img, cmap=plt.cm.gray)
ax1.imshow(color_mask);

# %%
# Convert the input image and color mask to Hue Saturation Value (HSV)
# colorspace
from skimage import color
img_hsv = color.rgb2hsv(img_color)
color_mask_hsv = color.rgb2hsv(color_mask)

# Construct RGB version of grey-level image
img_color = np.dstack((img, img, img))

# Replace the hue and saturation of the original image
# with that of the color mask
img_hsv[..., 0] = color_mask_hsv[..., 0]
img_hsv[..., 1] = color_mask_hsv[..., 1] * alpha

img_masked = color.hsv2rgb(img_hsv)

# Display the output
f, (ax0, ax1, ax2) = plt.subplots(1, 3,
                                  subplot_kw={'xticks': [], 'yticks': []},
                                  figsize=(12, 8))
ax0.imshow(img, cmap=plt.cm.gray)
ax1.imshow(color_mask)
ax2.imshow(img_masked)
plt.show()

# %% [markdown]
# ### Geometric Transformations

# %%
from skimage import transform

img = data.camera()

theta = np.deg2rad(30)
s = 0.8
C = np.cos(theta)
S = np.sin(theta)
tx, ty = 150, 0
s0, s1 = 0, 0

H = np.array([[s*C, -s*S, tx],
              [s*S,  s*C, ty],
              [s0,    s1, 1]])

print "Transformation matrix H is:"
print "\n", H, "\n"

img = data.camera()
tf = transform.ProjectiveTransform(H)
out = transform.warp(img, tf.inverse)

print "Origin maps to ->", tf([0, 0])

f, (ax0, ax1) = plt.subplots(1, 2, figsize=(10, 5))
ax0.imshow(img, cmap=plt.cm.gray)
ax1.imshow(out, cmap=plt.cm.gray);
# Out:
# Transformation matrix H is:
#
# [[   0.69282032   -0.4         150.        ]
#  [   0.4           0.69282032    0.        ]
#  [   0.            0.            1.        ]]
#
# Origin maps to -> [[ 150.    0.]]

# %% [markdown]
# ### Non-linear warping

# %%
from skimage import transform

image = data.lena()

def fisheye(xy):
    center = np.mean(xy, axis=0)
    xc, yc = (xy - center).T
    
    # Polar coordinates
    r = np.sqrt(xc**2 + yc**2)
    theta = np.arctan2(yc, xc)

    r = 0.87 * np.exp(r**(1/2.5) / 1.75)

    return np.column_stack((
        r * np.cos(theta), r * np.sin(theta)
        )) + center 

out = transform.warp(image, fisheye)

f, (ax0, ax1) = plt.subplots(1, 2)
ax0.imshow(image)
ax1.imshow(out);

# %% [markdown]
# ### Stand-alone demos: Canny + Hough visualizers

# %% [markdown]
# ### Block views and filtering

# %%
from skimage.util.shape import view_as_windows
img = data.camera()
img.shape
# Out:
# (512, 512)

# %%
w = view_as_windows(img, window_shape=(20, 20))
print w.shape
# Out:
# (493, 493, 20, 20)

# %%
img_max = w.max(axis=2).max(axis=2)
print img_max.shape
# Out:
# (493, 493)

# %%
io.imshow(img_max)

# %% [markdown]
# ### Histogram of gradients

# %%
from skimage.feature import hog
from skimage import data, color, exposure

image = data.camera()

fd, hog_image = hog(image, orientations=16, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualise=True)

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 0.02))

# Display results side-by-side

f, (ax0, ax1) = plt.subplots(1, 2, figsize=(10, 5))

ax0.set_axis_off()
ax0.imshow(image, cmap=plt.cm.gray)
ax0.set_title('Input image')

ax1.set_axis_off()
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax1.set_title('Histogram of Oriented Gradients')

plt.show()

# %% [markdown]
# ### Gallery examples
#
# [skimage gallery](http://scikits-image.org/docs/dev/auto_examples/index.html)

# %% [markdown]
# # Breakout
#
# Please choose one of the following problems to work on.
#
# ## Image registration
#
# Consider two satellite views of the same area:
#
# <pre>
# webreg_0.jpg webreg_1.jpg
# </pre>
#
# 1. Load and display the images.
# 2. Estimate the affine transform that would fit these images together.
# 3. Apply the transform and combine the two images.
#
# Hints:
#
#  - Look at ``skimage.transform``.
#  - Use matplotlib's ``ginput`` to find point coordinates.
#
# The process of aligning and combining images is known as "image registration".
#
#
# ## False-color image representation
#
# Consider the provided image files:
#
# <pre>
#   m8_050507_26i26m_L.png  m8_050507_9i9m_B.png  m8_050507_9i9m_R.png
#   m8_050507_5i75m_H.png   m8_050507_9i9m_G.png
# </pre>
#
# 1. Load and display the individual inputs
# 2. Add the inputs to form a single grey-level image
# 3. Now, combine these images into a single, color  image.  Apply denoising as
#    as you see fit.  An example pipeline is given here:
#
#   http://www.mistisoftware.com/astronomy/Process_m8.htm
#
# Hints:
#
#  - These images are enormous--scale them down before playing around.
#  - It may sometimes be easier to manipulate image colors in the HSV domain
#  - A colour image has dimensions ``(M, N, 3)`` for red, green and blue layers.
