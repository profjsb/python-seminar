# %%
import twil # this has Josh's secret keys there, as well as his phone numbers

# %%
from twilio.rest import TwilioRestClient

account = twil.SID
token = twil.TOKEN
client = TwilioRestClient(account, token)

message = client.sms.messages.create(to="+17346807846", from_=twil.TWILNUM,
                                     body="You need more sitar music in your life.")
# Out:
# ---------------------------------------------------------------------------
# TwilioRestException                       Traceback (most recent call last)
# <ipython-input-4-2a77c3dc804e> in <module>()
#       6
#       7 message = client.sms.messages.create(to="+17346807846", from_=twil.TWILNUM,
# ----> 8                                      body="You need more sitar music in your life.")
#
# /Users/jbloom/anaconda/python.app/Contents/lib/python2.7/site-packages/twilio/rest/resources/sms_messages.pyc in create(self, from_, **kwargs)
#     165         """
#     166         kwargs["from"] = from_
# --> 167         return self.create_instance(kwargs)
#     168
#     169     @normalize_dates
#
# /Users/jbloom/anaconda/python.app/Contents/lib/python2.7/site-packages/twilio/rest/resources/base.pyc in create_instance(self, body)
#     317         """
#     318         resp, instance = self.request("POST", self.uri,
# --> 319                                       data=transform_params(body))
#     320
#     321         if resp.status_code not in (200, 201):
#
# /Users/jbloom/anaconda/python.app/Contents/lib/python2.7/site-packages/twilio/rest/resources/base.pyc in request(self, method, uri, **kwargs)
#     169         if 'timeout' not in kwargs and self.timeout is not UNSET_TIMEOUT:
#     170             kwargs['timeout'] = self.timeout
# --> 171         resp = make_twilio_request(method, uri, auth=self.auth, **kwargs)
#     172
#     173         logging.debug(resp.content)
#
# /Users/jbloom/anaconda/python.app/Contents/lib/python2.7/site-packages/twilio/rest/resources/base.pyc in make_twilio_request(method, uri, **kwargs)
#     136             message = resp.content
#     137
# --> 138         raise TwilioRestException(resp.status_code, resp.url, message, code)
#     139
#     140     return resp
#
# TwilioRestException: HTTP ERROR 400: 21608: The number +17346807846 is unverified. Trial accounts cannot send messages to unverified numbers; verify +17346807846 at twilio.com/user/account/phone-numbers/verified, or purchase a Twilio number to send messages to unverified numbers.
#  https://api.twilio.com/2010-04-01/Accounts/AC95dcf9c8003bbd3c750266f6ea72d0b1/SMS/Messages.json

# %%
print message.status
# Out:
# queued

# %%
from twilio.rest import TwilioRestClient

# To find these visit https://www.twilio.com/user/account
ACCOUNT_SID = twil.SID
AUTH_TOKEN = twil.TOKEN

client = TwilioRestClient(ACCOUNT_SID, AUTH_TOKEN)
call = client.calls.create(to=twil.JOSHNUM, from_=twil.TWILNUM,
                           url="http://twimlets.com/holdmusic?Bucket=com.twilio.music.ambient")

# %%
print call.status
# Out:
# queued
